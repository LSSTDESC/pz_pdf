# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate 
import pandas as pd
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = (10,10)

# %% [markdown]
# We will use the PhotoZDC1 package, specifically photErrorModel, to create the errors, you can grab this package from GitHub with:<br>
# git clone https://github.com/LSSTDESC/PhotoZDC1.git <br>
# then add the location to your path, as below.  This implements the error model as defined in Ivezic et al (2008) (see: https://arxiv.org/abs/0805.2366 for details)
# We have already added a copy to the Photo-z group workspace at NERSC at:
# `/global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC1/PhotoZDC1/`

# %%
#Add the PhotoZDC1 package to the path and import photErrorModel that will be used to generate errors 
#sys.path.insert(0, '/global/u2/s/schmidt9/PhotoZDC1/src')
sys.path.insert(0, '/global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC1/PhotoZDC1/src/')
import photErrorModel as errMod

# %% [markdown]
# Set up the LSST Error Model parameters.  Alex used some defaults from the Science Book that are not quite the same as the newest numbers from the Science Drivers document (arxiv: 0805.2366v5), so update them here.  We'll use the following number of total visits in 10 years as listed in Table 1:
# NVISITS: u: 56  g: 80  r: 184  i: 184  z: 160  y: 160
#
# And check the error model parameters against those listed in Table 2:
# Nearly all values will have to be updated
#
# Note that we should use ''theta_eff'', not ''theta'' in the tables!
#
# There is a simple parameter to try to account for extended objects versus the point sources that these models are meant to approximate.  A quick discussion with Zeljko Ivezic and Andy Connolly years ago I believe decided on an offset in m5 value of 0.1 as a very rough approximation, so we'll add that with the errmodel.extendedsource = 0.1 parameter
#
# We can check the param settings with the .\_\_repr\_\_ method

# %%
errmodel = errMod.LSSTErrorModel()
errmodel.setRandomSeed(6687)
errmodel.tvis = 30.0
errmodel.nYrObs=10.0
visits = {'LSST_u':5.6, 'LSST_g':8.0, 'LSST_r':18.4, 'LSST_i':18.4,'LSST_z':16.0,'LSST_y':16.0}
errmodel.nVisYr=visits
msky = {'LSST_u':22.99, 'LSST_g':22.26, 'LSST_r':21.20, 'LSST_i':20.48,'LSST_z':19.60,
        'LSST_y':18.61}
errmodel.msky = msky
#theta = {'LSST_u':0.81, 'LSST_g':0.77, 'LSST_r':0.73, 'LSST_i':0.71,'LSST_z':0.69,'LSST_y':0.68}
theta = {'LSST_u':0.92, 'LSST_g':0.87, 'LSST_r':0.83, 'LSST_i':0.80,'LSST_z':0.78,'LSST_y':0.76}
errmodel.theta = theta
gamma = {'LSST_u':0.038, 'LSST_g':0.039, 'LSST_r':0.039, 'LSST_i':0.039,'LSST_z':0.039,
         'LSST_y':0.039}
errmodel.gamma = gamma
#cm = {'LSST_u':23.09, 'LSST_g':24.42, 'LSST_r':24.44, 'LSST_i':24.32,'LSST_z':24.16,'LSST_y':23.73}
cmshift = {'LSST_u':22.47, 'LSST_g':24.24, 'LSST_r':24.34, 'LSST_i':24.25,'LSST_z':24.11,
           'LSST_y':23.69}
errmodel.Cm = cmshift
km = {'LSST_u':0.491, 'LSST_g':0.213, 'LSST_r':0.126, 'LSST_i':0.096,'LSST_z':0.069,'LSST_y':0.170}
errmodel.km = km
errmodel.airMass = 1.2
errmodel.extendedSource=0.1
errmodel.sigmaSys = 0.005
errmodel.__repr__
# Out:
# updated random seed to new value 6687
# <bound method LSSTErrorModel.__repr__ of
#  LSSTErrorModel parameters:
#  Exposure time = 30.0 s
#  Number of years of observations = 10.0
#  Number of visits per year per band: {'LSST_u': 5.6, 'LSST_g': 8.0, 'LSST_r': 18.4, 'LSST_i': 18.4, 'LSST_z': 16.0, 'LSST_y': 16.0}
#  Systematic error = 0.005 mag
#  Airmass = 1.2
#  Sky brightness per band: {'LSST_u': 22.99, 'LSST_g': 22.26, 'LSST_r': 21.2, 'LSST_i': 20.48, 'LSST_z': 19.6, 'LSST_y': 18.61} (mag)
#  Seeing per band: {'LSST_u': 22.99, 'LSST_g': 22.26, 'LSST_r': 21.2, 'LSST_i': 20.48, 'LSST_z': 19.6, 'LSST_y': 18.61} (arcsec)
#  gamma per band: {'LSST_u': 0.038, 'LSST_g': 0.039, 'LSST_r': 0.039, 'LSST_i': 0.039, 'LSST_z': 0.039, 'LSST_y': 0.039}
#  Cm per band: {'LSST_u': 22.47, 'LSST_g': 24.24, 'LSST_r': 24.34, 'LSST_i': 24.25, 'LSST_z': 24.11, 'LSST_y': 23.69}
#  Extinction coeff. per band: {'LSST_u': 0.491, 'LSST_g': 0.213, 'LSST_r': 0.126, 'LSST_i': 0.096, 'LSST_z': 0.069, 'LSST_y': 0.17}
#  Extended source model: add 0.1 mag to 5-sigma depth for point sources
#  Minimum allowed observed flux = 2.5e-40
# >

# %% [markdown]
# Let's check the 5 sigma point source depths, which should equal the following numbers at Zenith (we need to account for the $\Delta Cm$ values which account for instrumental noise, listed below are m5 values minus the $\Delta Cm^{ \infty}$ values in Table 2 of the Ivezic paper)<br>
# u: 23.78 - 0.62 = 23.16<br>
# g: 24.81 - 0.18 = 24.63<br>
# r: 24.35 - 0.10 = 24.25<br>
# i: 23.92 - 0.07 = 23.85<br>
# z: 23.34 - 0.05 = 23.29<br>
# y: 22.45 - 0.04 = 22.41<br>

# %%
errfilts = ('LSST_u','LSST_g','LSST_r','LSST_i','LSST_z','LSST_y')
for filt in errfilts:
    print ("%s  %.2f"%(filt,errmodel._m5PointSources(cmshift[filt],msky[filt],theta[filt],30.,
                                                     km[filt],1.0)))
    #args are Cm, msky, theta, tvis (30 seconds), km, and X (airmass, set to zenith so 1.0)
# Out:
# LSST_u  23.17
# LSST_g  24.63
# LSST_r  24.26
# LSST_i  23.85
# LSST_z  23.29
# LSST_y  22.41

# %% [markdown]
# m5 values check out to the .01 level, so that is good!<br>

# %% [markdown]
# We will test on cosmoDC2v1.1.4_small, which has 51 hdf5 files for 17 healpix pixels broken into 3 redshift ranges.  When things are finalized we can switch to cosmoDC2_v1.1.4_image for the larger catalog

# %%
import GCRCatalogs
## check version
print('GCRCatalogs =', GCRCatalogs.__version__, '|' ,'GCR =', GCRCatalogs.GCR.__version__)
# Out:
# GCRCatalogs = 0.10.1 | GCR = 0.8.7

# %%
#use this to print all available catalogs, note the "False" to actually list them all
#print('\n'.join(sorted(GCRCatalogs.get_available_catalogs(False))))

# %%
#gc = GCRCatalogs.load_catalog('proto-dc2_v5.0')
gc = GCRCatalogs.load_catalog('cosmoDC2_v1.1.4_small')

# %%
#List all available quantities in the catalog
#print('\n'.join(sorted(gc.list_all_native_quantities())[:]))

# %% [markdown]
# Set up some names that we will use to grab the six LSST magnitudes from the catalog reader

# %%
filts = ('u','g','r','i','z','y')
short_mag_cols = []
mag_cols = []
for filt in filts:
    mag_cols.append('LSST_filters/magnitude:LSST_%s:observed:dustAtlas'%filt)
    short_mag_cols.append('lsst_%s'%filt)
all_cols = mag_cols
column_dict = dict(zip(mag_cols,short_mag_cols))
all_cols.append('redshift')
all_cols.append('baseDC2/galaxy_id')
print (filts,mag_cols)
# Out:
# ('u', 'g', 'r', 'i', 'z', 'y') ['LSST_filters/magnitude:LSST_u:observed:dustAtlas', 'LSST_filters/magnitude:LSST_g:observed:dustAtlas', 'LSST_filters/magnitude:LSST_r:observed:dustAtlas', 'LSST_filters/magnitude:LSST_i:observed:dustAtlas', 'LSST_filters/magnitude:LSST_z:observed:dustAtlas', 'LSST_filters/magnitude:LSST_y:observed:dustAtlas', 'redshift', 'baseDC2/galaxy_id']

# %% [markdown]
# We will be computing the model errors for our mock galaxies.  The error fuction produced by the PZDC1.getMagError function is very smooth.  Rather than computing this for every galaxy, we will compute a grid for each filter and interpolate between them to speed up the computation.  We will set an ad hoc upper limit of 35 for magnitude, above this magnitude we will set the spline to return 99.0.  This should only really occur for flux <= 0.0 and a NaN in the log(flux).

# %%
mag_min = 10.
mag_max = 45.
num_gridpts = 4001 #parameters for magerr_spline
mag_grid = np.linspace(mag_min,mag_max,num_gridpts)
#print (mag_grid)

# %% [markdown]
# Now, define the functions for making the spline and creating new magnitudes.  For scatterMag, we need to convert to flux, add Gaussian uncertainty, then convert back to flux.

# %%
def makeSpline(grid,filt):
    fx =  [errmodel.getMagError(x,filt) for x in grid]
    return fx

# %% [markdown]
# Now find the one sigma limiting magnitudes, where the error model is equal to 0.7525 magnitudes

# %%
one_sig_limits = []
for filt in errfilts:
    tmp_errs = makeSpline(mag_grid,filt)
    errspline = scipy.interpolate.interp1d(tmp_errs,mag_grid,kind='linear')
    onesig = errspline(0.7525)
    one_sig_limits.append(onesig)
one_sig_limits = np.array(one_sig_limits)
print (one_sig_limits)
# Out:
# [26.62082546 28.32221143 28.41300641 28.00897967 27.38598025 26.47897626]

# %%
def scatterMag(mag,mag_err):
    """Add proper uncertainty to magnitude
    Parmeters
    ---------
    mag: 'float' array-like
        true magnitudes 
    magerr: 'float' array-like
        magnitude uncertainties 
    Returns
    -------
    new_mag: 'float' array-like
        magnitudes with proper uncertainty, or 99 if flux was negative after error added
    """
    floor = 1.e-14 # set a minimum flux value, corresponding to mag = 35 for now
    floor_mag = -2.5*np.log10(floor)
    flux = np.power(10.,-0.4*mag) 
    err_flux = np.multiply(flux,mag_err)*0.4*np.log(10.)
    mask = (err_flux<0.0) #check for objects that have scattered to negative flux
    err_flux[mask] = 0.005
    tmperr = np.random.normal(0.0,err_flux)
    new_flux = np.subtract(flux,tmperr)
    mask = (new_flux < floor)
    new_flux[mask] = floor
    new_mag = -2.5*np.log10(new_flux)
    mask2 = np.logical_or(new_mag != new_mag,new_mag>=floor_mag)#error for NaN or Inf, which can happen if flux is negative or 0
    new_mag[mask2] = 99.0
    print ("Number of non-detections: %d"%(np.sum(mask2)))
    return new_mag

# %% [markdown]
# Set up an iterator to grab each healpix pixel, and also grab the native filenames.  We will create analagous filenames for our magnitues+errors and new uncertainties.

# %%
#print ("number of objects in catalog: %d"%(len(data['redshift'])))
gc_iterator = gc.get_quantities(all_cols,return_iterator=True)
fpath_iterator= gc._healpix_files.values()

# %%
base_output_path = "/global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/"
pz_filenames = []
for tmppath in fpath_iterator:
    filename = os.path.split(tmppath)[-1]
    basename = os.path.splitext(filename)[0]
    pz_filenames.append(base_output_path+basename+"_magwerr.h5")
print ('\n'.join(pz_filenames))
# Out:
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_10070_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_10071_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_10072_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_10198_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_10199_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_10200_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_10326_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_10327_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_10450_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_9559_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_9686_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_9687_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_9814_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_9815_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_9816_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_9942_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_0_1.step_all.healpix_9943_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_10070_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_10071_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_10072_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_10198_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_10199_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_10200_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_10326_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_10327_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_10450_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_9559_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_9686_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_9687_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_9814_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_9815_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_9816_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_9942_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_1_2.step_all.healpix_9943_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_10070_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_10071_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_10072_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_10198_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_10199_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_10200_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_10326_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_10327_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_10450_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_9559_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_9686_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_9687_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_9814_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_9815_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_9816_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_9942_magwerr.h5
# /global/projecta/projectdirs/lsst/groups/PZ/PhotoZDC2/COSMODC2v1.1.4/10_year_error_estimates/z_2_3.step_all.healpix_9943_magwerr.h5

# %%
print(len(pz_filenames))
# Out:
# 51

# %% [markdown]
# Next, for each filter, compute magnitude errors, add the uncertainties to the magnitudes, and re-calculate the magnitude errors.  Then add these new "scattered" (in flux) quantities to the data frame, and write out to hdf5 files.
#
# We will store them on cori in the file path listed above.

# %%
# %%time
pd.set_option('precision', 5)
cols_to_write=['redshift','baseDC2/galaxy_id']
for filt in filts:
    cols_to_write.append("mag_%s_obs"%filt)
    cols_to_write.append("magerr_%s_obs"%filt)
for data,tmpfile in zip(gc_iterator,pz_filenames):
    df = pd.DataFrame(data, columns = all_cols)
    for filt,magcol,maglim in zip(filts,mag_cols,one_sig_limits):
        print ("working on filter %s"%(filt))
        tmpmag = data[magcol]
        grid_errs = makeSpline(mag_grid,'LSST_%s'%filt)
        #print (grid_errs)
        errspline = scipy.interpolate.interp1d(mag_grid,grid_errs,kind='linear',bounds_error=False,
                                               fill_value=maglim)#return 99.0 outside interval
        newerrx = errspline(tmpmag)
        newmag = np.array(scatterMag(tmpmag,newerrx),dtype=np.float32)
        #we need to recalculate the magnitude error based on the new magnitude    
        newerr = np.array(errspline(newmag),dtype=np.float32)  
        magname = 'mag_%s_obs'%filt
        errname = 'magerr_%s_obs'%filt
        df[magname] = newmag
        df[errname] = newerr
    smalldf = df[cols_to_write]
    smalldf.to_hdf(tmpfile, 'df',mode='w')
# Out:
# working on filter u
# Number of non-detections: 875286
# working on filter g
# Number of non-detections: 386590
# working on filter r
# Number of non-detections: 181232
# working on filter i
# Number of non-detections: 119935
# working on filter z
# Number of non-detections: 189108
# working on filter y
# Number of non-detections: 395235
# working on filter u
# Number of non-detections: 876250
# working on filter g
# Number of non-detections: 387955
# working on filter r
# Number of non-detections: 180910
# working on filter i
# Number of non-detections: 119425
# working on filter z
# Number of non-detections: 188835
# working on filter y
# Number of non-detections: 396257
# working on filter u
# Number of non-detections: 873984
# working on filter g
# Number of non-detections: 387258
# working on filter r
# Number of non-detections: 180578
# working on filter i
# Number of non-detections: 119740
# working on filter z
# Number of non-detections: 189162
# working on filter y
# Number of non-detections: 395156
# working on filter u
# Number of non-detections: 873901
# working on filter g
# Number of non-detections: 386916
# working on filter r
# Number of non-detections: 180897
# working on filter i
# Number of non-detections: 120132
# working on filter z
# Number of non-detections: 188976
# working on filter y
# Number of non-detections: 394856
# working on filter u
# Number of non-detections: 879295
# working on filter g
# Number of non-detections: 388675
# working on filter r
# Number of non-detections: 181316
# working on filter i
# Number of non-detections: 119718
# working on filter z
# Number of non-detections: 188930
# working on filter y
# Number of non-detections: 395575
# working on filter u
# Number of non-detections: 878745
# working on filter g
# Number of non-detections: 386758
# working on filter r
# Number of non-detections: 179661
# working on filter i
# Number of non-detections: 120535
# working on filter z
# Number of non-detections: 188591
# working on filter y
# Number of non-detections: 395249
# working on filter u
# Number of non-detections: 883040
# working on filter g
# Number of non-detections: 388710
# working on filter r
# Number of non-detections: 180255
# working on filter i
# Number of non-detections: 119257
# working on filter z
# Number of non-detections: 188456
# working on filter y
# Number of non-detections: 396147
# working on filter u
# Number of non-detections: 876459
# working on filter g
# Number of non-detections: 387106
# working on filter r
# Number of non-detections: 180126
# working on filter i
# Number of non-detections: 119358
# working on filter z
# Number of non-detections: 188449
# working on filter y
# Number of non-detections: 396060
# working on filter u
# Number of non-detections: 876147
# working on filter g
# Number of non-detections: 387846
# working on filter r
# Number of non-detections: 180673
# working on filter i
# Number of non-detections: 119815
# working on filter z
# Number of non-detections: 188857
# working on filter y
# Number of non-detections: 395505
# working on filter u
# Number of non-detections: 879600
# working on filter g
# Number of non-detections: 387554
# working on filter r
# Number of non-detections: 181075
# working on filter i
# Number of non-detections: 120011
# working on filter z
# Number of non-detections: 189455
# working on filter y
# Number of non-detections: 395626
# working on filter u
# Number of non-detections: 877407
# working on filter g
# Number of non-detections: 388084
# working on filter r
# Number of non-detections: 180151
# working on filter i
# Number of non-detections: 119148
# working on filter z
# Number of non-detections: 188018
# working on filter y
# Number of non-detections: 395453
# working on filter u
# Number of non-detections: 882808
# working on filter g
# Number of non-detections: 388181
# working on filter r
# Number of non-detections: 181277
# working on filter i
# Number of non-detections: 120041
# working on filter z
# Number of non-detections: 188781
# working on filter y
# Number of non-detections: 395997
# working on filter u
# Number of non-detections: 879879
# working on filter g
# Number of non-detections: 387685
# working on filter r
# Number of non-detections: 180691
# working on filter i
# Number of non-detections: 120067
# working on filter z
# Number of non-detections: 188843
# working on filter y
# Number of non-detections: 395380
# working on filter u
# Number of non-detections: 879304
# working on filter g
# Number of non-detections: 387783
# working on filter r
# Number of non-detections: 180105
# working on filter i
# Number of non-detections: 119562
# working on filter z
# Number of non-detections: 189015
# working on filter y
# Number of non-detections: 395285
# working on filter u
# Number of non-detections: 880484
# working on filter g
# Number of non-detections: 388228
# working on filter r
# Number of non-detections: 180692
# working on filter i
# Number of non-detections: 119615
# working on filter z
# Number of non-detections: 188825
# working on filter y
# Number of non-detections: 395004
# working on filter u
# Number of non-detections: 877552
# working on filter g
# Number of non-detections: 387729
# working on filter r
# Number of non-detections: 180856
# working on filter i
# Number of non-detections: 120178
# working on filter z
# Number of non-detections: 188367
# working on filter y
# Number of non-detections: 396600
# working on filter u
# Number of non-detections: 877953
# working on filter g
# Number of non-detections: 387394
# working on filter r
# Number of non-detections: 179967
# working on filter i
# Number of non-detections: 119495
# working on filter z
# Number of non-detections: 189051
# working on filter y
# Number of non-detections: 394362
# working on filter u
# Number of non-detections: 2520760
# working on filter g
# Number of non-detections: 1494833
# working on filter r
# Number of non-detections: 1313941
# working on filter i
# Number of non-detections: 1407275
# working on filter z
# Number of non-detections: 1615085
# working on filter y
# Number of non-detections: 2005495
# working on filter u
# Number of non-detections: 2516742
# working on filter g
# Number of non-detections: 1491817
# working on filter r
# Number of non-detections: 1312936
# working on filter i
# Number of non-detections: 1407780
# working on filter z
# Number of non-detections: 1616882
# working on filter y
# Number of non-detections: 2006334
# working on filter u
# Number of non-detections: 2519111
# working on filter g
# Number of non-detections: 1497347
# working on filter r
# Number of non-detections: 1313096
# working on filter i
# Number of non-detections: 1410045
# working on filter z
# Number of non-detections: 1619389
# working on filter y
# Number of non-detections: 2008473
# working on filter u
# Number of non-detections: 2529424
# working on filter g
# Number of non-detections: 1497591
# working on filter r
# Number of non-detections: 1314611
# working on filter i
# Number of non-detections: 1413553
# working on filter z
# Number of non-detections: 1618611
# working on filter y
# Number of non-detections: 2010521
# working on filter u
# Number of non-detections: 2533177
# working on filter g
# Number of non-detections: 1496627
# working on filter r
# Number of non-detections: 1315198
# working on filter i
# Number of non-detections: 1410896
# working on filter z
# Number of non-detections: 1616996
# working on filter y
# Number of non-detections: 2009753
# working on filter u
# Number of non-detections: 2519904
# working on filter g
# Number of non-detections: 1496580
# working on filter r
# Number of non-detections: 1313339
# working on filter i
# Number of non-detections: 1411093
# working on filter z
# Number of non-detections: 1618773
# working on filter y
# Number of non-detections: 2009649
# working on filter u
# Number of non-detections: 2535213
# working on filter g
# Number of non-detections: 1500317
# working on filter r
# Number of non-detections: 1315853
# working on filter i
# Number of non-detections: 1412326
# working on filter z
# Number of non-detections: 1620358
# working on filter y
# Number of non-detections: 2013700
# working on filter u
# Number of non-detections: 2518435
# working on filter g
# Number of non-detections: 1493545
# working on filter r
# Number of non-detections: 1313742
# working on filter i
# Number of non-detections: 1410067
# working on filter z
# Number of non-detections: 1618292
# working on filter y
# Number of non-detections: 2008672
# working on filter u
# Number of non-detections: 2532301
# working on filter g
# Number of non-detections: 1498671
# working on filter r
# Number of non-detections: 1315254
# working on filter i
# Number of non-detections: 1411153
# working on filter z
# Number of non-detections: 1621059
# working on filter y
# Number of non-detections: 2011225
# working on filter u
# Number of non-detections: 2534664
# working on filter g
# Number of non-detections: 1501015
# working on filter r
# Number of non-detections: 1317603
# working on filter i
# Number of non-detections: 1414680
# working on filter z
# Number of non-detections: 1620830
# working on filter y
# Number of non-detections: 2014597
# working on filter u
# Number of non-detections: 2508936
# working on filter g
# Number of non-detections: 1491552
# working on filter r
# Number of non-detections: 1312524
# working on filter i
# Number of non-detections: 1407862
# working on filter z
# Number of non-detections: 1615071
# working on filter y
# Number of non-detections: 2006144
# working on filter u
# Number of non-detections: 2525409
# working on filter g
# Number of non-detections: 1497890
# working on filter r
# Number of non-detections: 1315112
# working on filter i
# Number of non-detections: 1411571
# working on filter z
# Number of non-detections: 1620331
# working on filter y
# Number of non-detections: 2013931
# working on filter u
# Number of non-detections: 2529185
# working on filter g
# Number of non-detections: 1496761
# working on filter r
# Number of non-detections: 1314906
# working on filter i
# Number of non-detections: 1411008
# working on filter z
# Number of non-detections: 1621357
# working on filter y
# Number of non-detections: 2013323
# working on filter u
# Number of non-detections: 2522940
# working on filter g
# Number of non-detections: 1496204
# working on filter r
# Number of non-detections: 1316271
# working on filter i
# Number of non-detections: 1411736
# working on filter z
# Number of non-detections: 1618009
# working on filter y
# Number of non-detections: 2013031
# working on filter u
# Number of non-detections: 2531920
# working on filter g
# Number of non-detections: 1498166
# working on filter r
# Number of non-detections: 1314315
# working on filter i
# Number of non-detections: 1411213
# working on filter z
# Number of non-detections: 1621063
# working on filter y
# Number of non-detections: 2010960
# working on filter u
# Number of non-detections: 2530241
# working on filter g
# Number of non-detections: 1496977
# working on filter r
# Number of non-detections: 1313034
# working on filter i
# Number of non-detections: 1408779
# working on filter z
# Number of non-detections: 1618436
# working on filter y
# Number of non-detections: 2009873
# working on filter u
# Number of non-detections: 2517555
# working on filter g
# Number of non-detections: 1494539
# working on filter r
# Number of non-detections: 1312979
# working on filter i
# Number of non-detections: 1408915
# working on filter z
# Number of non-detections: 1618725
# working on filter y
# Number of non-detections: 2006301
# working on filter u
# Number of non-detections: 3936379
# working on filter g
# Number of non-detections: 3033652
# working on filter r
# Number of non-detections: 2792447
# working on filter i
# Number of non-detections: 3061034
# working on filter z
# Number of non-detections: 3399072
# working on filter y
# Number of non-detections: 3724074
# working on filter u
# Number of non-detections: 3938420
# working on filter g
# Number of non-detections: 3035451
# working on filter r
# Number of non-detections: 2792335
# working on filter i
# Number of non-detections: 3062364
# working on filter z
# Number of non-detections: 3398588
# working on filter y
# Number of non-detections: 3720612
# working on filter u
# Number of non-detections: 3926594
# working on filter g
# Number of non-detections: 3028853
# working on filter r
# Number of non-detections: 2784849
# working on filter i
# Number of non-detections: 3056300
# working on filter z
# Number of non-detections: 3391902
# working on filter y
# Number of non-detections: 3718408
# working on filter u
# Number of non-detections: 3927480
# working on filter g
# Number of non-detections: 3028676
# working on filter r
# Number of non-detections: 2786962
# working on filter i
# Number of non-detections: 3053965
# working on filter z
# Number of non-detections: 3394208
# working on filter y
# Number of non-detections: 3719222
# working on filter u
# Number of non-detections: 3938145
# working on filter g
# Number of non-detections: 3036118
# working on filter r
# Number of non-detections: 2788767
# working on filter i
# Number of non-detections: 3061046
# working on filter z
# Number of non-detections: 3396507
# working on filter y
# Number of non-detections: 3725644
# working on filter u
# Number of non-detections: 3936184
# working on filter g
# Number of non-detections: 3034509
# working on filter r
# Number of non-detections: 2790667
# working on filter i
# Number of non-detections: 3059001
# working on filter z
# Number of non-detections: 3396093
# working on filter y
# Number of non-detections: 3726275
# working on filter u
# Number of non-detections: 3951425
# working on filter g
# Number of non-detections: 3044068
# working on filter r
# Number of non-detections: 2797481
# working on filter i
# Number of non-detections: 3067140
# working on filter z
# Number of non-detections: 3406649
# working on filter y
# Number of non-detections: 3736538
# working on filter u
# Number of non-detections: 3936859
# working on filter g
# Number of non-detections: 3033671
# working on filter r
# Number of non-detections: 2788345
# working on filter i
# Number of non-detections: 3062262
# working on filter z
# Number of non-detections: 3394875
# working on filter y
# Number of non-detections: 3724757
# working on filter u
# Number of non-detections: 3926549
# working on filter g
# Number of non-detections: 3032748
# working on filter r
# Number of non-detections: 2787434
# working on filter i
# Number of non-detections: 3057808
# working on filter z
# Number of non-detections: 3393808
# working on filter y
# Number of non-detections: 3716873
# working on filter u
# Number of non-detections: 3928588
# working on filter g
# Number of non-detections: 3032344
# working on filter r
# Number of non-detections: 2787332
# working on filter i
# Number of non-detections: 3057128
# working on filter z
# Number of non-detections: 3391671
# working on filter y
# Number of non-detections: 3721779
# working on filter u
# Number of non-detections: 3951018
# working on filter g
# Number of non-detections: 3042361
# working on filter r
# Number of non-detections: 2793690
# working on filter i
# Number of non-detections: 3067866
# working on filter z
# Number of non-detections: 3404467
# working on filter y
# Number of non-detections: 3736667
# working on filter u
# Number of non-detections: 3911113
# working on filter g
# Number of non-detections: 3022991
# working on filter r
# Number of non-detections: 2781699
# working on filter i
# Number of non-detections: 3052668
# working on filter z
# Number of non-detections: 3380793
# working on filter y
# Number of non-detections: 3709256
# working on filter u
# Number of non-detections: 3944335
# working on filter g
# Number of non-detections: 3035475
# working on filter r
# Number of non-detections: 2787414
# working on filter i
# Number of non-detections: 3061265
# working on filter z
# Number of non-detections: 3400699
# working on filter y
# Number of non-detections: 3726875
# working on filter u
# Number of non-detections: 3936657
# working on filter g
# Number of non-detections: 3033486
# working on filter r
# Number of non-detections: 2788077
# working on filter i
# Number of non-detections: 3060636
# working on filter z
# Number of non-detections: 3394799
# working on filter y
# Number of non-detections: 3723548
# working on filter u
# Number of non-detections: 3927752
# working on filter g
# Number of non-detections: 3027734
# working on filter r
# Number of non-detections: 2785266
# working on filter i
# Number of non-detections: 3054045
# working on filter z
# Number of non-detections: 3391192
# working on filter y
# Number of non-detections: 3713765
# working on filter u
# Number of non-detections: 3926530
# working on filter g
# Number of non-detections: 3027149
# working on filter r
# Number of non-detections: 2786482
# working on filter i
# Number of non-detections: 3054164
# working on filter z
# Number of non-detections: 3389991
# working on filter y
# Number of non-detections: 3714877
# working on filter u
# Number of non-detections: 3912597
# working on filter g
# Number of non-detections: 3020882
# working on filter r
# Number of non-detections: 2780389
# working on filter i
# Number of non-detections: 3050490
# working on filter z
# Number of non-detections: 3382000
# working on filter y
# Number of non-detections: 3708028
# CPU times: user 9min 21s, sys: 1min 15s, total: 10min 36s
# Wall time: 11min 18s
